# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
fig, ax = plt.subplots()
plt.plot(x, cos, label='Cosx', color='red')
plt.plot(x, cos3, linestyle='--', label='3 Cosx', color='green')
plt.plot(x, sin, linestyle='-.', label='Sin(x-90)', color='blue')
plt.plot(x, sin2, linestyle='None', marker='x', label='2 Sinx', color='#d0d046')

# mengubah axis label dan title
ax.set_xlabel('X-Axis Label ')
ax.set_ylabel('Y-Axis Label')
ax.set_title('Grafik Cos Sin')

ax.legend( loc="center")

plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
